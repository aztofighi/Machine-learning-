# %% [markdown]
# <a href="https://colab.research.google.com/github/aztofighi/MachineLearning/blob/main/Ml_Exercise11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1115cdc5-2505-47aa-8e14-d262bbc010ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1115cdc5-2505-47aa-8e14-d262bbc010ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('/content/train.csv')

num_samples = 50

# انتخاب داده‌های تصادفی و متناظر با برچسب‌ها
random_indices = np.random.choice(data.index, num_samples, replace=False)
random_data = data.loc[random_indices]
print(random_data)
# Out:
#            x1        x2  labels
# 19   1.427997  2.499021     0.0
# 53   2.633861  0.683641     1.0
# 57   1.237597  0.513187     1.0
# 125 -1.554930  0.621129     0.0
# 114  2.697327  1.124837     0.0
# 3    1.745329  2.482572     0.0
# 98  -1.872262  0.500009     0.0
# 18  -3.078126  1.424294     0.0
# 120 -1.808796 -0.933327     1.0
# 142 -1.935729 -0.294879     1.0
# 116  0.666398  1.545990     0.0
# 22   2.887727  0.794539     1.0
# 70  -1.491463 -0.778072     1.0
# 65   1.110664  2.025660     0.0
# 145 -2.379994 -0.987225     1.0
# 81  -1.618396  0.543232     0.0
# 127 -0.412532  1.759302     0.0
# 60   1.681863  0.904004     1.0
# 78  -1.554930 -0.878871     1.0
# 23  -0.793331 -0.533272     1.0
# 4    2.887727  2.294539     0.0
# 33  -0.475999 -0.240200     1.0
# 133  1.427997  0.999021     1.0
# 84   0.222133  0.267689     1.0
# 140 -0.475999  1.259800     0.0
# 148 -2.887727 -0.762502     1.0
# 39  -2.062662  1.392741     0.0
# 6   -1.110664 -0.955600     1.0
# ...

# %%
# انتخاب 50 داده تصادفی برای اعتبارسنجی
num_validation_samples = 50
validation_indices = np.random.choice(len(scaled_data), num_validation_samples, replace=False)
validation_data = scaled_data[validation_indices]
validation_labels = labels[validation_indices]
# Out:
#            x1        x2  labels
# 0   -1.872262 -0.999991     1.0
# 1   -1.047198  0.500973     0.0
# 2    0.031733 -0.286129     1.0
# 3    1.745329  2.482572     0.0
# 4    2.887727  2.294539     0.0
# ..        ...       ...     ...
# 145 -2.379994 -0.987225     1.0
# 146 -0.666398  0.789406     0.0
# 147  2.506927  2.398750     0.0
# 148 -2.887727 -0.762502     1.0
# 149 -2.379994  0.512775     0.0
#
# [150 rows x 3 columns]

# %%
x1 = normalized_data['x1']
x2=normalized_data['x2']
plt.scatter(x1,x2, label='نقاط', color='blue', marker='o')
plt.show()

# %%
Class1 = random_data['x1']
Class2=random_data['x2']
plt.scatter(Class1,Class2, label='نقاط', color='green', marker='o')
plt.show()

# %%
labels = data['labels']
x1 = data['x1']
x2 = data['x2']
for i in range(len(x1)):

    if labels[i] == 0:
        plt.scatter(x1[i], x2[i], label=labels[i],  color='red', marker='1')

    elif labels[i] == 1:
        plt.scatter(x1[i], x2[i], label=labels[i], color='blue', marker='o')

# %%
labels = data['labels']
x1 = normalized_data['x1']
x2 = normalized_data['x2']
for i in range(len(x1)):

    if labels[i] == 0:
        plt.scatter(x1[i], x2[i], label=labels[i],  color='red', marker='o')

    elif labels[i] == 1:
        plt.scatter(x1[i], x2[i], label=labels[i], color='blue', marker='o')
